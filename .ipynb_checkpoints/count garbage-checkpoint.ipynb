# %%
import os
import numpy as np
import pandas as pd
from sklearn.feature_extraction.text import CountVectorizer
import sqlalchemy as sq
import re
from tqdm import tqdm
import jieba

# %%
defaultList = []
cedictList = []

# %%
defaultdict = r"""C:\Users\jw\Anaconda3\Lib\site-packages\jieba\dict.txt.big.txt"""

# %%
defaultdict
# Out:
# 'C:\\Users\\jw\\Anaconda3\\Lib\\site-packages\\jieba\\dict.txt.big.txt'

# %%
f = open(defaultdict, "r",encoding="utf8")
for x in f:
    defaultList.append(re.split(string=x,pattern="\s",maxsplit=1)[0])

# %%
cedict = r"""C:\Users\jw\Downloads\cedict_1_0_ts_utf-8_mdbg\cedict_ts.txt"""

# %%
f = open(cedict, "r",encoding="utf8")
for x in f:
    cedictList.append(re.split(string=x,pattern="\s",maxsplit=2)[1])

# %%
defaultList
# Out:
# ['1号店',
#  '1號店',
#  '4S店',
#  '4s店',
#  'AA制',
#  'AB型',
#  'AT&T',
#  'A型',
#  'A座',
#  'A股',
#  'A輪',
#  'A轮',
#  'BB机',
#  'BB機',
#  'BP机',
#  'BP機',
#  'B型',
#  'B座',
#  'B股',
#  'B超',
#  'B輪',
#  'B轮',
#  'C#',
#  'C++',
#  'CALL机',
#  'CALL機',
#  'CD机',
#  'CD機',
#  'CD盒',
#  'C座',
#  'C盘',
#  'C盤',
#  'C語言',
#  'C语言',
#  'D座',
#  'D版',
#  'D盘',
#  'D盤',
#  'E化',
#  'E座',
#  'E盘',
#  'E盤',
#  'E通',
#  'F座',
#  'F盘',
#  'F盤',
#  'G盘',
#  'G盤',
#  'H盘',
#  'H盤',
#  'H股',
#  'IC卡',
#  'IP卡',
#  'IP地址',
#  'IP电话',
#  'IP電話',
#  'I盘',
#  'I盤',
#  'K党',
#  'K歌之王',
#  'K黨',
#  'N年',
#  'O型',
#  'PC机',
#  'PC機',
#  'PH值',
#  'QQ号',
#  'QQ號',
#  'Q版',
#  'RSS訂閱',
#  'RSS订阅',
#  'SIM卡',
#  'T台',
#  'T型台',
#  'T型臺',
#  'T恤',
#  'T恤衫',
#  'T盘',
#  'T盤',
#  'T臺',
#  'U盘',
#  'U盤',
#  'VISA卡',
#  'X光',
#  'X光線',
#  'X光线',
#  'X射線',
#  'X射线',
#  'Z盘',
#  'Z盤',
#  'c#',
#  'c++',
#  'γ射線',
#  'γ射线',
#  '䰾',
#  '䲁',
#  '䴉',
#  '一',
#  '一一',
#  '一一二',
#  '一一例',
#  '一一分',
#  '一一列举',
#  '一一列舉',
# ...

# %%
len(defaultList)
# Out:
# 584429

# %%
len(cedictList)
# Out:
# 116982

# %%
len(set(defaultList).intersection(set(cedictList)))
# Out:
# 82237

# %%
len(set(defaultList).union(set(cedictList)))
# Out:
# 614682

# %%
cedictList
# Out:
# ['%',
#  '21三体综合症',
#  '3C',
#  '3P',
#  '3Q',
#  '502胶',
#  '88',
#  '996',
#  'A',
#  'AA制',
#  'AB制',
#  'ACG',
#  'A咖',
#  'A圈儿',
#  'A片',
#  'A菜',
#  'A货',
#  'B',
#  'BP机',
#  'B型超声',
#  'B超',
#  'CP',
#  'C位',
#  'C盘',
#  'C罗',
#  'DNA鉴定',
#  'E仔',
#  'G友',
#  'G弦裤',
#  'G点',
#  'H桥',
#  'K人',
#  'K仔',
#  'K他命',
#  'K房',
#  'K书',
#  'K歌',
#  'K粉',
#  'K线',
#  'K线图',
#  'K金',
#  'L照',
#  'MV',
#  'M巾',
#  'N久',
#  'N挡',
#  'OK绷',
#  'OK镜',
#  'OS',
#  'O型腿',
#  'P',
#  'PK',
#  'PO',
#  'PO文',
#  'PU',
#  'P图',
#  'P挡',
#  'P民',
#  'Q',
#  'Q劲',
#  'Q弹',
#  'T',
#  'TA',
#  'T字帐',
#  'T字裤',
#  'T恤',
#  'T裇',
#  'USB手指',
#  'USB记忆棒',
#  'U凸内裤',
#  'U型枕',
#  'U型池',
#  'U形转弯',
#  'U盘',
#  'U盾',
#  'VCR',
#  'V沟',
#  'XO酱',
#  'X光',
#  'cos',
#  'π日',
#  '□',
#  '□',
#  '○',
#  '⺮',
#  '々',
#  '〇',
#  '〡',
#  '〢',
#  '〣',
#  '〤',
#  '〥',
#  '〦',
#  '〧',
#  '〨',
#  '〩',
#  '〻',
#  '㍻',
#  '㍼',
#  '㍽',
#  '㍾',
#  '㐄',
#  '㐅',
#  '㐆',
#  '㐌',
#  '㐖',
#  '㐖毒',
#  '㐜',
#  '㐡',
#  '㐤',
# ...

# %%
import codecs
with codecs.open('cedict.txt', 'w', "utf-8") as f:
    for item in cedictList:
        f.write("{}\n".format(item))

# %%
# jieba.load_userdict(file_name)

# %%
from bs4 import BeautifulSoup
from selenium import webdriver
# from selenium.webdriver.firefox.options import Options
from selenium.webdriver.chrome.options import Options
import re
import sys
import time
import numpy as np
import pandas as pd
import os
import psycopg2
from tqdm import tqdm


# conn = psycopg2.connect(host="chinaquant.cofdbub8go3o.eu-west-1.rds.amazonaws.com",
#                     database="postgres",
#                     user="tokyo3",
#                     password="evangelion")

# cur = conn.cursor()

# command = """
# SELECT *
# FROM documents
# WHERE doc_content IS NOT NULL and doc_date IS NOT NULL and doc_html IS NOT NULL

# """

# cur.execute(command)
# existing = cur.fetchall()
# cur.close()
# conn.close()


conn = psycopg2.connect(host="chinaquant.cofdbub8go3o.eu-west-1.rds.amazonaws.com",
                    database="postgres",
                    user="tokyo3",
                    password="evangelion")

cur = conn.cursor()

command = """
SELECT doc_country, doc_page_name, doc_url, doc_date, doc_content
FROM documents
WHERE doc_content IS NOT NULL and doc_date IS NOT NULL and doc_html IS NOT NULL

"""

cur.execute(command)
existing = cur.fetchall()
cur.close()
conn.close()

# %%
existing[:2]
# Out:
# [('尼日利亚',
#   '驻外报道',
#   'https://www.fmprc.gov.cn/web/gjhdq_676201/gj_676203/fz_677316/1206_678356/1206x2_678376/t1134035.shtml',
#   datetime.date(2014, 3, 4),
#   '\n\u3000\u30002014年3月3日，驻拉各斯总领事刘侃拜会拉各斯州州长法萧拉。\n\n\u3000\u3000刘总领事感谢法萧拉州长的热情接待，表示来尼之后，已感受到拉各斯人民的热情和友好，称赞拉各斯州近些年在州长领导下发展迅速。刘总领事表示，中国政府重视发展中尼关系，鼓励更多中国企业、人员来尼投资，指出中国企业在拉各斯发展势头良好，为拉各斯社会、经济的发展做出了贡献，这离不开州政府的支持，总领馆将继续推动拉各斯州与中国有关方面的合作，希望法萧拉州长一如既往的支持总领馆的工作。\n\n\u3000\u3000法萧拉州长祝贺刘侃总领事出任中国驻拉各斯总领事，称赞中国取得的成就，是尼日利亚学习的榜样，表示拉各斯州与中国有关方面一直保持良好的合作关系，州政府将继续支持总领馆的工作。法萧拉州长向刘总领事致以中国马年祝福，并祝中尼关系能在新的一年里不断发展、马力十足。\n'),
#  ('瑞士',
#   '驻外报道',
#   'https://www.fmprc.gov.cn/web/gjhdq_676201/gj_676203/oz_678770/1206_679618/1206x2_679638/t823147.shtml',
#   datetime.date(2011, 5, 17),
# ...

# %%
len(existing)
# Out:
# 132035

# %%
columns = ["doc_country","doc_page_name","doc_url","doc_date","doc_content"]

# %%
data = pd.DataFrame(existing, columns=columns)

# %%
data.head()
# Out:
#   doc_country doc_page_name  \
# 0        尼日利亚          驻外报道
# 1          瑞士          驻外报道
# 2         喀麦隆          驻外报道
# 3         喀麦隆          驻外报道
# 4        尼日利亚          驻外报道
#
#                                              doc_url    doc_date  \
# 0  https://www.fmprc.gov.cn/web/gjhdq_676201/gj_6...  2014-03-04
# 1  https://www.fmprc.gov.cn/web/gjhdq_676201/gj_6...  2011-05-17
# 2  https://www.fmprc.gov.cn/web/gjhdq_676201/gj_6...  2009-01-27
# 3  https://www.fmprc.gov.cn/web/gjhdq_676201/gj_6...  2009-01-17
# 4  https://www.fmprc.gov.cn/web/gjhdq_676201/gj_6...  2014-02-28
#
#                                          doc_content
# 0  \n　　2014年3月3日，驻拉各斯总领事刘侃拜会拉各斯州州长法萧拉。\n\n　　刘总领事感...
# 1  \n　　2011年5月16日，驻瑞士大使吴恳在大使馆会见到馆的中国侨联代表团和参加座谈的旅瑞...
# 2  \n　　2009年1月26日正月初一，中国驻喀麦隆大使黄长庆前往我援喀医疗队姆巴尔马约分队驻...
# 3  \n　　2009年1月16日，中国驻喀麦隆大使黄长庆在官邸举行2009年新春招待会，驻喀中资...
# 4  \n　　2014年2月27日，驻拉各斯总领事刘侃会见河流州哈克特港市工商矿农协会主席艾默卡一...

# %%
data['doc_content'] = data['doc_content'].str.strip().copy()

# %%
data.head()
# Out:
#   doc_country doc_page_name  \
# 0        尼日利亚          驻外报道
# 1          瑞士          驻外报道
# 2         喀麦隆          驻外报道
# 3         喀麦隆          驻外报道
# 4        尼日利亚          驻外报道
#
#                                              doc_url    doc_date  \
# 0  https://www.fmprc.gov.cn/web/gjhdq_676201/gj_6...  2014-03-04
# 1  https://www.fmprc.gov.cn/web/gjhdq_676201/gj_6...  2011-05-17
# 2  https://www.fmprc.gov.cn/web/gjhdq_676201/gj_6...  2009-01-27
# 3  https://www.fmprc.gov.cn/web/gjhdq_676201/gj_6...  2009-01-17
# 4  https://www.fmprc.gov.cn/web/gjhdq_676201/gj_6...  2014-02-28
#
#                                          doc_content
# 0  2014年3月3日，驻拉各斯总领事刘侃拜会拉各斯州州长法萧拉。\n\n　　刘总领事感谢法萧拉...
# 1  2011年5月16日，驻瑞士大使吴恳在大使馆会见到馆的中国侨联代表团和参加座谈的旅瑞华侨华人...
# 2  2009年1月26日正月初一，中国驻喀麦隆大使黄长庆前往我援喀医疗队姆巴尔马约分队驻地看望援...
# 3  2009年1月16日，中国驻喀麦隆大使黄长庆在官邸举行2009年新春招待会，驻喀中资机构、专...
# 4  2014年2月27日，驻拉各斯总领事刘侃会见河流州哈克特港市工商矿农协会主席艾默卡一行。\n...

# %%
from sklearn.feature_extraction.text import CountVectorizer, TfidfTransformer, TfidfVectorizer

# %%
jieba.set_dictionary(defaultdict)

# %%
jieba.load_userdict("cedict.txt")
# Out:
# Building prefix dict from C:\Users\jw\Anaconda3\Lib\site-packages\jieba\dict.txt.big.txt ...
# Dumping model to file cache C:\Users\jw\AppData\Local\Temp\jieba.uab1e068561d2ba60d2eefedd4d3a6562.cache
# Loading model cost 1.187 seconds.
# Prefix dict has been built succesfully.

# %%
jieba.dt
# Out:
# <Tokenizer dictionary='C:\\Users\\jw\\Anaconda3\\Lib\\site-packages\\jieba\\dict.txt.big.txt'>

# %%
s = data.loc[4,'doc_content']

# %%
seg_list = jieba.cut(s, cut_all=True)
print("Full Mode: " + " ".join(seg_list))  # 全模式
print()
seg_list = jieba.cut(s, cut_all=False)
print("Default Mode: " + " ".join(seg_list))  # 默认模式
# Out:
# Full Mode: 2014 年 2 月 27 日   驻 拉各斯 总领事 领事 刘 侃 会见 河流 州 哈克 克特 港市 工商 矿 农协 农协会 协会 协会主席 会主 主席 艾 默 卡 一行
#
#    刘 总领事 领事 欢迎 艾 默 卡 主席 来 馆 访问   向 艾 简要 简要介绍 介绍 了 中尼 双边 双边关系 边关 关系   经贸 往来 情况   指出 河流 州 经济 实力 仅次于 次于 拉各斯 州   有 不少 少华 华侨 华人   中资 公司 在 该州 生产   经营   哈科特 哈科特港 科特 港 是 尼日 尼日利亚 日利 利亚 重要 港口 港口城市 城市   总领馆 领馆 重视 发展 与 河流 州 各界 的 关系   欢迎 河流 州 更多 有 实力 的 企业   商人 到 中国 从事 商贸 活动
#
#    艾 默 卡 主席 感谢 刘 总领事 领事 热情 热情接待 接待   简要 简要介绍 介绍 了 协会 情况   表示 愿 与 总领馆 领馆 建立 良好 关系   将 努力 力推 推动 河流 州 与 中国 国有 有关 方面 经贸 交流 与 合作   艾 并邀 邀请 刘 总领事 领事 来 河流 州 访问
#    河流 州 哈克 克特 港 工商 矿 农协 农协会 协会 目前 拥有 包括 在 该州 投资 经营 的 外国 外国公司 国公 公司 在内 的 900 多 会员   单位    是 尼 最大 的 工商 工商企业 企业 业协会 协会
#
# Default Mode: 2014 年 2 月 27 日 ， 驻 拉各斯 总领事 刘侃 会见 河流 州 哈克 特 港市 工商 矿 农协会 主席 艾默卡 一行 。
#
#  　 　 刘 总领事 欢迎 艾默卡 主席 来馆 访问 ， 向 艾 简要介绍 了 中尼 双边关系 、 经贸 往来 情况 ， 指出 河流 州 经济 实力 仅次于 拉各斯 州 ， 有 不少 华侨 华人 、 中资 公司 在 该州 生产 、 经营 ， 哈科特港 是 尼日利亚 重要 港口城市 ， 总领馆 重视 发展 与 河流 州 各界 的 关系 ， 欢迎 河流 州 更 多 有 实力 的 企业 、 商人 到 中国 从事 商贸 活动 。
#
# ...

# %%
data['doc_content'].str.replace(pat="\W", repl=" ")
# Out:
# 0         2014年3月3日 驻拉各斯总领事刘侃拜会拉各斯州州长法萧拉     刘总领事感谢法萧拉州长...
# 1         2011年5月16日 驻瑞士大使吴恳在大使馆会见到馆的中国侨联代表团和参加座谈的旅瑞华侨华人...
# 2         2009年1月26日正月初一 中国驻喀麦隆大使黄长庆前往我援喀医疗队姆巴尔马约分队驻地看望援...
# 3         2009年1月16日 中国驻喀麦隆大使黄长庆在官邸举行2009年新春招待会 驻喀中资机构 专...
# 4         2014年2月27日 驻拉各斯总领事刘侃会见河流州哈克特港市工商矿农协会主席艾默卡一行   ...
# 5         2014年2月26日 驻拉各斯总领馆刘侃总领事接受尼日利亚新闻社高级国际关系记者采访 就中尼...
# 6         2014年2月10日 驻拉各斯总领事刘侃访问尼日利亚国际关系研究院并与研究院院长阿金特林瓦教...
# 7         2014年1月31日至2月4日春节假日期间 驻尼日利亚拉各斯总领事刘侃分别走访慰问莱基自贸区...
# 8         2014年2月2日 驻拉各斯总领事刘侃出席董氏集团主办的 迎新春 活动 董氏集团员工 有关中...
# 9         问 据新加坡 联合早报 报道 新加坡总理李显龙访美期间表示 海牙仲裁庭的裁决对各国的主权声索...
# 10        2013年2月7日 驻阿联酋大使黄杰民出席由阿联酋扎耶德大学孔子学院和英国布莱顿学校阿布扎比...
# 11        2014年1月18日 驻拉各斯总领馆举行刘侃总领事到任招待会暨2014新春招待会 领区拉各斯...
# 12        各位来宾 各位朋友 女士们 先生们    下午好  感谢大家出席今天的招待会    我是上周...
# 13        2014年1月16日 驻尼日利亚大使邓波清在尼日利亚中国文化中心举办离任招待会 尼文化部长杜...
# 14        2013年7月28日 中国驻科威特使馆武官王瑞正大校在皇冠假日酒店举办招待会 热烈庆祝中国人...
# 15        2013年2月8日 驻科威特大使崔建春和夫人梁慧丽以及使馆部分外交官应邀出席科威特华侨华人协...
# ...

# %%
jieba.lcut(s, cut_all=True)
# Out:
# ['2014',
#  '年',
#  '2',
#  '月',
#  '27',
#  '日',
#  '',
#  '',
#  '驻',
#  '拉各斯',
#  '总领事',
#  '领事',
#  '刘',
#  '侃',
#  '会见',
#  '河流',
#  '州',
#  '哈克',
#  '克特',
#  '港市',
#  '工商',
#  '矿',
#  '农协',
#  '农协会',
#  '协会',
#  '协会主席',
#  '会主',
#  '主席',
#  '艾',
#  '默',
#  '卡',
#  '一行',
#  '',
#  '\n\n',
#  '',
#  '',
#  '刘',
#  '总领事',
#  '领事',
#  '欢迎',
#  '艾',
#  '默',
#  '卡',
#  '主席',
#  '来',
#  '馆',
#  '访问',
#  '',
#  '',
#  '向',
#  '艾',
#  '简要',
#  '简要介绍',
#  '介绍',
#  '了',
#  '中尼',
#  '双边',
#  '双边关系',
#  '边关',
#  '关系',
#  '',
#  '',
#  '经贸',
#  '往来',
#  '情况',
#  '',
#  '',
#  '指出',
#  '河流',
#  '州',
#  '经济',
#  '实力',
#  '仅次于',
#  '次于',
#  '拉各斯',
#  '州',
#  '',
#  '',
#  '有',
#  '不少',
#  '少华',
#  '华侨',
#  '华人',
#  '',
#  '',
#  '中资',
#  '公司',
#  '在',
#  '该州',
#  '生产',
#  '',
#  '',
#  '经营',
#  '',
#  '',
#  '哈科特',
#  '哈科特港',
#  '科特',
#  '港',
#  '是',
#  '尼日',
#  '尼日利亚',
#  '日利',
#  '利亚',
#  '重要',
#  '港口',
#  '港口城市',
#  '城市',
#  '',
#  '',
#  '总领馆',
#  '领馆',
#  '重视',
#  '发展',
#  '与',
#  '河流',
# ...

# %%
def my_tokenizer(s):
    return jieba.lcut(s, cut_all=True)

# %%
count = CountVectorizer(tokenizer=my_tokenizer)

# %%
count.fit(data['doc_content'])

# %%
len(count.get_feature_names())
