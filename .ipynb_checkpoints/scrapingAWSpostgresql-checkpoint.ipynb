# %%
from bs4 import BeautifulSoup
from selenium import webdriver
from selenium.webdriver.firefox.options import Options
import re
import sys
import time

import numpy as np
import pandas as pd
import os
import psycopg2

from tqdm import tqdm

# %%
try:
    skiplist = list(pd.read_csv('skiplist.csv',index_col=0,header=None).iloc[:,0])
except:
    skiplist = []

# %%
skiplist
# Out:
# [115922,
#  119509,
#  119510,
#  18780,
#  25273,
#  28631,
#  29112,
#  31395,
#  32583,
#  33032,
#  33276,
#  115922,
#  119509,
#  119510,
#  25273,
#  115922,
#  119509,
#  119510,
#  25273,
#  67583,
#  68459,
#  80854,
#  100,
#  1000,
#  100000,
#  100024,
#  10008,
#  100082,
#  100086,
#  100088,
#  100092,
#  100094,
#  100098,
#  100100,
#  100122,
#  100143,
#  100151,
#  100153,
#  100160,
#  116398,
#  10018,
#  100186,
#  100192,
#  100195,
#  100209,
#  100221,
#  100222,
#  100230,
#  100236,
#  104692,
#  100245,
#  100247,
#  10026,
#  100263,
#  100271,
#  100274,
#  100279,
#  100281,
#  100297,
#  10031,
#  100333,
#  100334,
#  100337,
#  10035,
#  100358,
#  10036,
#  100367,
#  100369,
#  10037,
#  100371,
#  100387,
#  100388,
#  100390,
#  100418,
#  101909,
#  102057,
#  102058,
#  102059,
#  10206,
#  102060,
#  102061,
#  102062,
#  102063,
#  102064,
#  102065,
#  102066,
#  102067,
#  102068,
#  102069,
#  102070,
#  102071,
#  102072,
#  102073,
#  102074,
#  102075,
#  102076,
#  102077,
#  102078,
#  102079,
#  10208,
#  102080,
#  102081,
#  102082,
#  102083,
#  102084,
#  102085,
#  102086,
#  102087,
#  102088,
#  102089,
#  10209,
#  102090,
#  102091,
#  102092,
#  102093,
#  102094,
#  102095,
#  102096,
#  102097,
#  102098,
#  102099,
#  1021,
#  10210,
#  102100,
#  102101,
#  102102,
#  102103,
#  102104,
#  102105,
#  102106,
#  102107,
#  102108,
#  102109,
#  102110,
#  102111,
#  102112,
#  102113,
#  102114,
#  102115,
#  102116,
#  102117,
#  102118,
#  102119,
#  10212,
#  102120,
#  102121,
#  102122,
#  102123,
#  102124,
#  102125,
#  102126,
#  102127,
#  102128,
#  102129,
#  102130,
#  102131,
#  102132,
#  102133,
#  102134,
#  102135,
#  102136,
#  102137,
#  102138,
#  102139,
#  10214,
#  102140,
#  102141,
#  102142,
#  102143,
#  102144,
#  102145,
#  102146,
#  102147,
#  102148,
#  102149,
#  10215,
#  102150,
#  102151,
#  102152,
#  102153,
#  102154,
#  102155,
#  102156,
#  102157,
#  102158,
#  102159,
#  10216,
#  102160,
#  102161,
#  102162,
#  102163,
#  102164,
#  102165,
#  102166,
#  102167,
#  102168,
#  102169,
#  10217,
#  102170,
#  102171,
#  102172,
#  102173,
#  102174,
#  102175,
#  102176,
#  102177,
#  102178,
#  102179,
#  10218,
#  102180,
#  102181,
#  102182,
#  102183,
#  102184,
#  102185,
#  102186,
#  102187,
#  102188,
#  102189,
#  10219,
#  102190,
#  102191,
#  102192,
#  102193,
#  102194,
#  102195,
#  102196,
#  102197,
#  102198,
#  102199,
#  1022,
#  10220,
#  102200,
#  102201,
#  102202,
#  102203,
#  102204,
#  102205,
#  102206,
#  102207,
#  102208,
#  102209,
#  10221,
#  102210,
#  102211,
#  102212,
#  102213,
#  102214,
#  102215,
#  102216,
#  102217,
#  102218,
#  102219,
#  10222,
#  102220,
#  102221,
#  102222,
#  102223,
#  102224,
#  102225,
#  102226,
#  102227,
#  102228,
#  102229,
#  10223,
#  102230,
#  102231,
#  102232,
#  102233,
#  102234,
#  102235,
#  102236,
#  102237,
#  102238,
#  102239,
#  10224,
#  102240,
#  102241,
#  102242,
#  102243,
#  102244,
#  102245,
#  102246,
#  102247,
#  102248,
#  102249,
#  102250,
#  102251,
#  102252,
#  102253,
#  102254,
#  102255,
#  102256,
#  102257,
#  102258,
#  102320,
#  10234,
#  102340,
#  102341,
#  102342,
#  102343,
#  102344,
#  102345,
#  102346,
#  102347,
#  102348,
#  102349,
#  10235,
#  102350,
#  102351,
#  102352,
#  102353,
#  102354,
#  102355,
#  102356,
#  102357,
#  102358,
#  102359,
#  102360,
#  102361,
#  102362,
#  102363,
#  102364,
#  102365,
#  102366,
#  102367,
#  103370,
#  103420,
#  103421,
#  103422,
#  103423,
#  103424,
#  103425,
#  103426,
#  103427,
#  103429,
#  10343,
#  103430,
#  103431,
#  103432,
#  103433,
#  103434,
#  103435,
#  103436,
#  103437,
#  103438,
#  103439,
#  10344,
#  103440,
#  103441,
#  103442,
#  103443,
#  103444,
#  103445,
#  103446,
#  103447,
#  103448,
#  103449,
#  10345,
#  52309,
#  103450,
#  103451,
#  103452,
#  103453,
#  103454,
#  103455,
#  103456,
#  103457,
#  103458,
#  103459,
#  10346,
#  103460,
#  103461,
#  103462,
#  103463,
#  103464,
#  103465,
#  103466,
#  103467,
#  103468,
#  103469,
#  103470,
#  103471,
#  103472,
#  103473,
#  103474,
#  103475,
#  103476,
#  103477,
#  103478,
#  103479,
#  10348,
#  103480,
#  103481,
#  103482,
#  103483,
#  103484,
#  103485,
#  103486,
#  103487,
#  103488,
#  103489,
#  10349,
#  103490,
#  103491,
#  103492,
#  103493,
#  103494,
#  103495,
#  103496,
#  103497,
#  103498,
#  103499,
#  1035,
#  10350,
#  103500,
#  103501,
#  103502,
#  103503,
#  103504,
#  103505,
#  103506,
#  103507,
#  103508,
#  103509,
#  10351,
#  103510,
#  103511,
#  103512,
#  103513,
#  103514,
#  103515,
#  103516,
#  103517,
#  103518,
#  103519,
#  10352,
#  103520,
#  103521,
#  103522,
#  103523,
#  103524,
#  103525,
#  103526,
#  103527,
#  103528,
#  103529,
#  10353,
#  103530,
#  103531,
#  103532,
#  103533,
#  103534,
#  103535,
#  103536,
#  103537,
#  103538,
#  103539,
#  10354,
#  103540,
#  103541,
#  103542,
#  103543,
#  103544,
#  103545,
#  103546,
#  103547,
#  103548,
#  103549,
#  10355,
#  103550,
#  103551,
#  103552,
#  5311,
#  103553,
#  103554,
#  103555,
#  103556,
#  103557,
#  103558,
#  103559,
#  10356,
#  103560,
#  103561,
#  103562,
#  103563,
#  103564,
#  103565,
#  103566,
#  103568,
#  103569,
#  10357,
#  103570,
#  103571,
#  103572,
#  103573,
#  103574,
#  103575,
#  103576,
#  103577,
#  103578,
#  103579,
#  103580,
#  103581,
#  103582,
#  103583,
#  103584,
#  103585,
#  103586,
#  103587,
#  103588,
#  103589,
#  10359]

# %%
conn = psycopg2.connect(host="chinaquant.cofdbub8go3o.eu-west-1.rds.amazonaws.com",
                        database="postgres",
                        user="tokyo3",
                        password="evangelion")

cur = conn.cursor()

# %%
command = """
SELECT doc_id,doc_url
FROM documents
WHERE doc_html IS NULL AND doc_date IS NOT NULL and doc_id NOT IN {}
LIMIT 5
""".format(tuple(skiplist))

cur.execute(command)

existing = cur.fetchall()

# %%
existing
# Out:
# [(1036,
#   'https://www.fmprc.gov.cn/web/gjhdq_676201/gjhdqzz_681964/lhg_682278/zyjh_682288/t1209481.shtml'),
#  (10360,
#   'https://www.fmprc.gov.cn/web/gjhdq_676201/gj_676203/yz_676205/1206_676884/1206x2_676904/t287742.shtml'),
#  (103600,
#   'https://www.fmprc.gov.cn/web/gjhdq_676201/gj_676203/dyz_681240/1206_681242/1206x2_681262/t1536932.shtml'),
#  (103601,
#   'https://www.fmprc.gov.cn/web/gjhdq_676201/gj_676203/dyz_681240/1206_681242/1206x2_681262/t1536691.shtml'),
#  (103602,
#   'https://www.fmprc.gov.cn/web/gjhdq_676201/gj_676203/dyz_681240/1206_681242/1206x2_681262/t1536687.shtml')]

# %%
conn = psycopg2.connect(host="chinaquant.cofdbub8go3o.eu-west-1.rds.amazonaws.com",
                    database="postgres",
                    user="tokyo3",
                    password="evangelion")

cur = conn.cursor()

command = """
SELECT count(doc_id)
FROM documents
WHERE doc_html IS NULL AND doc_date IS NOT NULL and doc_id NOT IN {}

""".format(tuple(skiplist))

cur.execute(command)

existing = cur.fetchall()

# %%
existing
# Out:
# [(109279,)]

# %%
command = """
SELECT column_name
FROM information_schema.columns
WHERE table_name = 'documents'
"""

cur.execute(command)

columns = cur.fetchall()

# %%
columns
# Out:
# [('doc_id',),
#  ('doc_country',),
#  ('doc_language',),
#  ('doc_page_name',),
#  ('doc_url',),
#  ('doc_nav',),
#  ('doc_title',),
#  ('doc_date',),
#  ('doc_html',),
#  ('doc_content',)]

# %%
def html(url):
    try:
        driver.get(url)
        html = driver.page_source
        if type(html) == str:
            return(html)
        else:
            return('ERROR')
    except:
        return('ERROR')

# %%
def headlessDriver():
    options = Options()
    options.add_argument("--headless")
    driver = webdriver.Firefox(options=options, executable_path="geckodriver.exe")
    return(driver)

# %%
def buildEntry(index_value,url):
    t_start = time.time()
    
    index = index_value
    pageSource = html(url)
#     pageDate = str()
    pageText = str()
    if pageSource == 'ERROR':
#         pageDate = 'ERROR'
        pageText = 'ERROR'
    else:
        try:
            soup=BeautifulSoup(pageSource, 'lxml')
#             pageDate = soup.find("span", {"id": "News_Body_Time"}).text
#             if pageDate == '':
#                 pageDate = None
            pageText = soup.find(class_='content').text
            if pageText == '':
                pageText = None
        except:
#             pageDate = 'ERROR'
            pageText = 'ERROR'
    
    entry = (pageSource,
#              pageDate,
             pageText,
             index)
    
    t_end = time.time()
    
    duration = t_end - t_start
    
    if duration >= 10:
        time.sleep(np.random.randint(5,15))
    
#   print(duration)          
    return(entry)

# %%
conn = psycopg2.connect(host="chinaquant.cofdbub8go3o.eu-west-1.rds.amazonaws.com",
                    database="postgres",
                    user="tokyo3",
                    password="evangelion")

cur = conn.cursor()

command = """
SELECT doc_id,doc_url
FROM documents
WHERE doc_html IS NULL AND doc_date IS NOT NULL and doc_id NOT IN {}
LIMIT 10
""".format(tuple(skiplist))

cur.execute(command)

existing = cur.fetchall()

cur.close()
conn.close()

# %%
def fullHarvest():
    t = time.time()
    try:
        skiplist = list(pd.read_csv('skiplist.csv',index_col=0,header=None).iloc[:,0])
    except:
        skiplist = []
        
    
    limit = 1
    
    conn = psycopg2.connect(host="chinaquant.cofdbub8go3o.eu-west-1.rds.amazonaws.com",
                        database="postgres",
                        user="tokyo3",
                        password="evangelion")

    cur = conn.cursor()
    
    command = """
    SELECT doc_id,doc_url
    FROM documents
    WHERE doc_html IS NULL AND doc_date IS NOT NULL and doc_id NOT IN {}
    LIMIT {}
    """.format(tuple(skiplist),limit)

    cur.execute(command)

    existing = cur.fetchall()
#     print(existing)
    cur.close()
    conn.close()
    
#     driver = None
#     driver = headlessDriver()
    submission = [buildEntry(int(x[0]),str(x[1])) for x in existing]
    
    newSubmission = []
    for i in submission:
        if i[1] == 'ERROR':
            skiplist.append(i[2])
        else:
            newSubmission.append(i)
    
    
    pd.Series(skiplist).to_csv('skiplist.csv')
    
    
    sub_len = len(newSubmission)
    
    
    
    
    conn = psycopg2.connect(host="chinaquant.cofdbub8go3o.eu-west-1.rds.amazonaws.com",
                        database="postgres",
                        user="tokyo3",
                        password="evangelion")

    cur = conn.cursor()
    sql = """
        UPDATE documents
        SET doc_html = %s,doc_content = %s
        WHERE doc_id = %s;
        """

    cur.executemany(sql,newSubmission)
    conn.commit()
    
    
    command = """
    SELECT COUNT(doc_id)
    FROM documents
    WHERE doc_html IS NULL AND doc_date IS NOT NULL and doc_id NOT IN {}
    """.format(tuple(skiplist))


    cur.execute(command)

    count = cur.fetchall()
    

    cur.close()
    conn.close()
    
    nt = time.time()
    dt = nt - t
    
    
    
    return(len(skiplist),count,dt,sub_len,existing)

# %%
counter = 0
driver = headlessDriver()

for i in tqdm(range(300)):    
    s,r,t,l,e = fullHarvest()
    print("{} : {:.4f}s : {} skips : {} remaining".format(i,t,s,r))
    if l == 0:
        print(e)
        counter += 1
        if counter > 5:
            break
        else:
            time.sleep(np.random.randint(30,60))
# Out:
#   0%|          | 0/300 [00:00<?, ?it/s]
# 0 : 11.9193s : 881 skips : [(108241,)] remaining
#   0%|          | 1/300 [00:11<59:25, 11.92s/it]
# 1 : 7.6470s : 881 skips : [(108240,)] remaining
#   1%|          | 2/300 [00:19<52:51, 10.64s/it]
# 2 : 8.3471s : 881 skips : [(108239,)] remaining
#   1%|          | 3/300 [00:27<49:16,  9.96s/it]
# 3 : 8.5845s : 881 skips : [(108238,)] remaining
#   1%|▏         | 4/300 [00:36<47:05,  9.55s/it]
# 4 : 8.5574s : 881 skips : [(108237,)] remaining
#   2%|▏         | 5/300 [00:45<45:29,  9.25s/it]
# 5 : 9.4160s : 881 skips : [(108236,)] remaining
#   2%|▏         | 6/300 [00:54<45:35,  9.30s/it]
# 6 : 7.5765s : 881 skips : [(108235,)] remaining
#   2%|▏         | 7/300 [01:02<42:55,  8.79s/it]
# 7 : 8.6971s : 881 skips : [(108234,)] remaining
#   3%|▎         | 8/300 [01:10<42:39,  8.77s/it]
# 8 : 7.2093s : 881 skips : [(108233,)] remaining
#   3%|▎         | 9/300 [01:18<40:16,  8.30s/it]
# 9 : 8.4443s : 881 skips : [(108232,)] remaining
#   3%|▎         | 10/300 [01:26<40:20,  8.35s/it]
# 10 : 9.5776s : 881 skips : [(108231,)] remaining
#   4%|▎         | 11/300 [01:36<42:00,  8.72s/it]
# 11 : 8.1295s : 881 skips : [(108230,)] remaining
#   4%|▍         | 12/300 [01:44<41:01,  8.55s/it]
# 12 : 8.7528s : 881 skips : [(108229,)] remaining
#   4%|▍         | 13/300 [01:52<41:11,  8.61s/it]
# 13 : 8.0317s : 881 skips : [(108228,)] remaining
#   5%|▍         | 14/300 [02:01<40:13,  8.44s/it]
# 14 : 8.9777s : 881 skips : [(108227,)] remaining
#   5%|▌         | 15/300 [02:10<40:52,  8.60s/it]
# 15 : 9.3653s : 881 skips : [(108226,)] remaining
#   5%|▌         | 16/300 [02:19<41:49,  8.84s/it]
# 16 : 9.0115s : 881 skips : [(108225,)] remaining
#   6%|▌         | 17/300 [02:28<41:55,  8.89s/it]
# 17 : 8.5760s : 881 skips : [(108224,)] remaining
#   6%|▌         | 18/300 [02:36<41:20,  8.80s/it]
# 18 : 9.8599s : 881 skips : [(108223,)] remaining
#   6%|▋         | 19/300 [02:46<42:42,  9.12s/it]
# 19 : 10.1769s : 881 skips : [(108222,)] remaining
#   7%|▋         | 20/300 [02:57<44:02,  9.44s/it]
# 20 : 11.3286s : 881 skips : [(108221,)] remaining
#   7%|▋         | 21/300 [03:08<46:32, 10.01s/it]
# 21 : 9.5378s : 881 skips : [(108220,)] remaining
#   7%|▋         | 22/300 [03:17<45:44,  9.87s/it]
# 22 : 14.5011s : 881 skips : [(108219,)] remaining
#   8%|▊         | 23/300 [03:32<52:00, 11.27s/it]
# 23 : 7.9880s : 881 skips : [(108218,)] remaining
#   8%|▊         | 24/300 [03:40<47:18, 10.28s/it]
# 24 : 10.5528s : 881 skips : [(108217,)] remaining
#   8%|▊         | 25/300 [03:51<47:31, 10.37s/it]
# 25 : 8.7300s : 881 skips : [(108216,)] remaining
#   9%|▊         | 26/300 [03:59<45:07,  9.88s/it]
# 26 : 9.3696s : 881 skips : [(108215,)] remaining
#   9%|▉         | 27/300 [04:09<44:16,  9.73s/it]
# 27 : 10.4537s : 881 skips : [(108214,)] remaining
#   9%|▉         | 28/300 [04:19<45:06,  9.95s/it]
# 28 : 8.1350s : 881 skips : [(108213,)] remaining
#  10%|▉         | 29/300 [04:27<42:28,  9.41s/it]
# 29 : 8.6910s : 881 skips : [(108212,)] remaining
#  10%|█         | 30/300 [04:36<41:21,  9.19s/it]
# 30 : 8.3953s : 881 skips : [(108211,)] remaining
#  10%|█         | 31/300 [04:44<40:09,  8.96s/it]
# 31 : 10.3488s : 881 skips : [(108210,)] remaining
#  11%|█         | 32/300 [04:55<41:53,  9.38s/it]
# 32 : 31.8957s : 881 skips : [(108209,)] remaining
#  11%|█         | 33/300 [05:27<1:11:48, 16.14s/it]
# 33 : 8.5959s : 881 skips : [(108208,)] remaining
#  11%|█▏        | 34/300 [05:35<1:01:31, 13.88s/it]
# 34 : 10.9805s : 881 skips : [(108207,)] remaining
#  12%|█▏        | 35/300 [05:46<57:28, 13.01s/it]
# 35 : 9.7710s : 881 skips : [(108206,)] remaining
#  12%|█▏        | 36/300 [05:56<52:59, 12.04s/it]
# 36 : 7.3886s : 881 skips : [(108205,)] remaining
#  12%|█▏        | 37/300 [06:03<46:41, 10.65s/it]
# 37 : 10.9687s : 881 skips : [(108204,)] remaining
#  13%|█▎        | 38/300 [06:14<46:56, 10.75s/it]
# 38 : 7.0412s : 881 skips : [(108203,)] remaining
#  13%|█▎        | 39/300 [06:21<41:56,  9.64s/it]
# 39 : 14.9577s : 882 skips : [(108202,)] remaining
# [(104369, 'https://www.fmprc.gov.cn/web/gjhdq_676201/gj_676203/dyz_681240/1206_681242/1206x2_681262/t1126306.shtml')]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-72-23da985e7e18> in <module>
#      11             break
#      12         else:
# ---> 13             time.sleep(np.random.randint(30,60))
#      14
#
# KeyboardInterrupt:

# %%
# buildEntry(104328,"https://www.fmprc.gov.cn/web/gjhdq_676201/gj_676203/dyz_681240/1206_681242/1206x2_681262/t1145802.shtml")

# %%
# driver = headlessDriver()
# buildEntry(102358,"""https://www.fmprc.gov.cn/web/gjhdq_676201/gj_676203/nmz_680924/1206_681192/1206x2_681212/t878484.shtml""")

# %%
try:
    skiplist = list(pd.read_csv('skiplist.csv',index_col=0,header=None).iloc[:,0])
except:
    skiplist = []

# %%
len(skiplist)
# Out:
# 882

# %%
skiplist
# Out:
# [115922,
#  119509,
#  119510,
#  18780,
#  25273,
#  28631,
#  29112,
#  31395,
#  32583,
#  33032,
#  33276,
#  115922,
#  119509,
#  119510,
#  25273,
#  115922,
#  119509,
#  119510,
#  25273,
#  67583,
#  68459,
#  80854,
#  100,
#  1000,
#  100000,
#  100024,
#  10008,
#  100082,
#  100086,
#  100088,
#  100092,
#  100094,
#  100098,
#  100100,
#  100122,
#  100143,
#  100151,
#  100153,
#  100160,
#  116398,
#  10018,
#  100186,
#  100192,
#  100195,
#  100209,
#  100221,
#  100222,
#  100230,
#  100236,
#  104692,
#  100245,
#  100247,
#  10026,
#  100263,
#  100271,
#  100274,
#  100279,
#  100281,
#  100297,
#  10031,
#  100333,
#  100334,
#  100337,
#  10035,
#  100358,
#  10036,
#  100367,
#  100369,
#  10037,
#  100371,
#  100387,
#  100388,
#  100390,
#  100418,
#  101909,
#  102057,
#  102058,
#  102059,
#  10206,
#  102060,
#  102061,
#  102062,
#  102063,
#  102064,
#  102065,
#  102066,
#  102067,
#  102068,
#  102069,
#  102070,
#  102071,
#  102072,
#  102073,
#  102074,
#  102075,
#  102076,
#  102077,
#  102078,
#  102079,
#  10208,
#  102080,
#  102081,
#  102082,
#  102083,
#  102084,
#  102085,
#  102086,
#  102087,
#  102088,
#  102089,
#  10209,
#  102090,
#  102091,
#  102092,
#  102093,
#  102094,
#  102095,
#  102096,
#  102097,
#  102098,
#  102099,
#  1021,
#  10210,
#  102100,
#  102101,
#  102102,
#  102103,
#  102104,
#  102105,
#  102106,
#  102107,
#  102108,
#  102109,
#  102110,
#  102111,
#  102112,
#  102113,
#  102114,
#  102115,
#  102116,
#  102117,
#  102118,
#  102119,
#  10212,
#  102120,
#  102121,
#  102122,
#  102123,
#  102124,
#  102125,
#  102126,
#  102127,
#  102128,
#  102129,
#  102130,
#  102131,
#  102132,
#  102133,
#  102134,
#  102135,
#  102136,
#  102137,
#  102138,
#  102139,
#  10214,
#  102140,
#  102141,
#  102142,
#  102143,
#  102144,
#  102145,
#  102146,
#  102147,
#  102148,
#  102149,
#  10215,
#  102150,
#  102151,
#  102152,
#  102153,
#  102154,
#  102155,
#  102156,
#  102157,
#  102158,
#  102159,
#  10216,
#  102160,
#  102161,
#  102162,
#  102163,
#  102164,
#  102165,
#  102166,
#  102167,
#  102168,
#  102169,
#  10217,
#  102170,
#  102171,
#  102172,
#  102173,
#  102174,
#  102175,
#  102176,
#  102177,
#  102178,
#  102179,
#  10218,
#  102180,
#  102181,
#  102182,
#  102183,
#  102184,
#  102185,
#  102186,
#  102187,
#  102188,
#  102189,
#  10219,
#  102190,
#  102191,
#  102192,
#  102193,
#  102194,
#  102195,
#  102196,
#  102197,
#  102198,
#  102199,
#  1022,
#  10220,
#  102200,
#  102201,
#  102202,
#  102203,
#  102204,
#  102205,
#  102206,
#  102207,
#  102208,
#  102209,
#  10221,
#  102210,
#  102211,
#  102212,
#  102213,
#  102214,
#  102215,
#  102216,
#  102217,
#  102218,
#  102219,
#  10222,
#  102220,
#  102221,
#  102222,
#  102223,
#  102224,
#  102225,
#  102226,
#  102227,
#  102228,
#  102229,
#  10223,
#  102230,
#  102231,
#  102232,
#  102233,
#  102234,
#  102235,
#  102236,
#  102237,
#  102238,
#  102239,
#  10224,
#  102240,
#  102241,
#  102242,
#  102243,
#  102244,
#  102245,
#  102246,
#  102247,
#  102248,
#  102249,
#  102250,
#  102251,
#  102252,
#  102253,
#  102254,
#  102255,
#  102256,
#  102257,
#  102258,
#  102320,
#  10234,
#  102340,
#  102341,
#  102342,
#  102343,
#  102344,
#  102345,
#  102346,
#  102347,
#  102348,
#  102349,
#  10235,
#  102350,
#  102351,
#  102352,
#  102353,
#  102354,
#  102355,
#  102356,
#  102357,
#  102358,
#  102359,
#  102360,
#  102361,
#  102362,
#  102363,
#  102364,
#  102365,
#  102366,
#  102367,
#  103370,
#  103420,
#  103421,
#  103422,
#  103423,
#  103424,
#  103425,
#  103426,
#  103427,
#  103429,
#  10343,
#  103430,
#  103431,
#  103432,
#  103433,
#  103434,
#  103435,
#  103436,
#  103437,
#  103438,
#  103439,
#  10344,
#  103440,
#  103441,
#  103442,
#  103443,
#  103444,
#  103445,
#  103446,
#  103447,
#  103448,
#  103449,
#  10345,
#  52309,
#  103450,
#  103451,
#  103452,
#  103453,
#  103454,
#  103455,
#  103456,
#  103457,
#  103458,
#  103459,
#  10346,
#  103460,
#  103461,
#  103462,
#  103463,
#  103464,
#  103465,
#  103466,
#  103467,
#  103468,
#  103469,
#  103470,
#  103471,
#  103472,
#  103473,
#  103474,
#  103475,
#  103476,
#  103477,
#  103478,
#  103479,
#  10348,
#  103480,
#  103481,
#  103482,
#  103483,
#  103484,
#  103485,
#  103486,
#  103487,
#  103488,
#  103489,
#  10349,
#  103490,
#  103491,
#  103492,
#  103493,
#  103494,
#  103495,
#  103496,
#  103497,
#  103498,
#  103499,
#  1035,
#  10350,
#  103500,
#  103501,
#  103502,
#  103503,
#  103504,
#  103505,
#  103506,
#  103507,
#  103508,
#  103509,
#  10351,
#  103510,
#  103511,
#  103512,
#  103513,
#  103514,
#  103515,
#  103516,
#  103517,
#  103518,
#  103519,
#  10352,
#  103520,
#  103521,
#  103522,
#  103523,
#  103524,
#  103525,
#  103526,
#  103527,
#  103528,
#  103529,
#  10353,
#  103530,
#  103531,
#  103532,
#  103533,
#  103534,
#  103535,
#  103536,
#  103537,
#  103538,
#  103539,
#  10354,
#  103540,
#  103541,
#  103542,
#  103543,
#  103544,
#  103545,
#  103546,
#  103547,
#  103548,
#  103549,
#  10355,
#  103550,
#  103551,
#  103552,
#  5311,
#  103553,
#  103554,
#  103555,
#  103556,
#  103557,
#  103558,
#  103559,
#  10356,
#  103560,
#  103561,
#  103562,
#  103563,
#  103564,
#  103565,
#  103566,
#  103568,
#  103569,
#  10357,
#  103570,
#  103571,
#  103572,
#  103573,
#  103574,
#  103575,
#  103576,
#  103577,
#  103578,
#  103579,
#  103580,
#  103581,
#  103582,
#  103583,
#  103584,
#  103585,
#  103586,
#  103587,
#  103588,
#  103589,
#  10359,
#  103612,
#  103613,
#  103614,
#  103615,
#  103616,
#  103617,
#  103618,
#  103619,
#  10362,
#  103620,
#  103621,
#  103622,
#  103623,
#  103624,
#  103625,
#  103626,
#  103627,
#  103628,
#  103629,
#  10363,
#  103630,
#  103631,
#  103632,
#  103633,
#  103634,
#  103635,
#  103636,
#  103637,
#  103638,
#  103639,
#  10364,
#  103640,
#  103641,
#  103642,
#  103643,
#  103644,
#  103645,
#  103646,
#  103647,
#  103648,
#  103649,
#  10365,
#  103650,
#  103651,
#  103652,
#  103653,
#  103654,
#  103655,
#  103656,
#  103657,
#  103658,
#  103659,
#  10366,
#  103660,
#  103661,
#  103662,
#  103663,
#  103664,
#  103665,
#  103666,
#  103667,
#  103668,
#  103669,
#  10367,
#  103670,
#  103671,
#  103672,
#  103673,
#  103674,
#  103675,
#  103676,
#  103677,
#  103678,
#  103679,
#  10368,
#  103680,
#  103681,
#  103682,
#  103683,
#  103684,
#  103685,
#  103686,
#  103687,
#  103688,
#  103689,
#  103690,
#  103691,
#  103692,
#  103693,
#  103694,
#  103695,
#  103696,
#  103697,
#  103698,
#  103699,
#  1037,
#  10370,
#  103700,
#  103701,
#  103702,
#  103703,
#  103704,
#  103705,
#  103706,
#  103707,
#  103708,
#  103709,
#  10371,
#  103710,
#  103711,
#  103712,
#  103713,
#  103714,
#  103715,
#  103716,
#  103717,
#  103718,
#  103719,
#  103720,
#  103721,
#  103722,
#  103723,
#  103724,
#  103725,
#  103726,
#  103727,
#  103728,
#  103729,
#  10373,
#  103730,
#  103731,
#  103732,
#  103733,
#  103734,
#  103735,
#  103736,
#  103737,
#  103738,
#  103739,
#  10374,
#  103740,
#  103741,
#  103742,
#  103743,
#  103744,
#  103745,
#  103746,
#  103747,
#  103748,
#  103749,
#  10375,
#  103750,
#  103751,
#  103752,
#  103753,
#  103754,
#  103755,
#  103756,
#  103757,
#  103758,
#  103759,
#  10376,
#  103760,
#  103761,
#  103762,
#  103763,
#  103764,
#  103765,
#  103766,
#  103767,
#  103768,
#  103769,
#  10377,
#  103770,
#  103771,
#  103772,
#  103773,
#  103774,
#  103775,
#  103776,
#  103777,
#  103778,
#  103779,
#  103780,
#  103781,
#  103782,
#  103783,
#  103784,
#  103785,
#  103786,
#  103787,
#  103788,
#  103789,
#  103790,
#  103791,
#  103792,
#  103793,
#  103794,
#  103795,
#  103796,
#  103797,
#  103798,
#  103799,
#  1038,
#  103800,
#  103801,
#  103802,
#  103803,
#  103804,
#  103805,
#  103806,
#  103807,
#  103808,
#  103809,
#  10381,
#  103810,
#  103811,
#  103812,
#  103813,
#  103814,
#  103815,
#  103816,
#  103817,
#  103818,
#  103819,
#  10382,
#  103820,
#  103821,
#  103822,
#  103823,
#  103824,
#  103825,
#  103826,
#  103827,
#  103828,
#  103829,
#  10383,
#  103830,
#  103831,
#  103832,
#  103833,
#  103834,
#  103835,
#  103836,
#  103837,
#  103838,
#  103839,
#  10384,
#  103840,
#  103841,
#  103842,
#  103843,
#  103844,
#  103845,
#  103846,
#  103847,
#  103848,
#  103849,
#  10385,
#  5439,
#  103850,
#  103851,
#  103852,
#  103853,
#  103854,
#  103855,
#  113897,
#  118705,
#  119207,
#  119209,
#  119210,
#  119211,
#  119215,
#  119216,
#  125246,
#  16658,
#  60135,
#  85105,
#  67583,
#  68459,
#  80854,
#  20417,
#  115922,
#  119509,
#  119510,
#  25273,
#  104257,
#  104258,
#  104259,
#  10426,
#  104260,
#  104261,
#  104262,
#  104263,
#  104264,
#  104265,
#  104266,
#  104267,
#  104268,
#  104269,
#  10427,
#  104270,
#  104271,
#  104272,
#  104273,
#  104274,
#  104275,
#  104276,
#  104277,
#  104278,
#  104279,
#  10428,
#  104280,
#  104281,
#  104282,
#  104283,
#  104284,
#  104285,
#  104286,
#  104287,
#  104288,
#  104586,
#  104289,
#  10429,
#  104290,
#  104291,
#  104292,
#  104293,
#  104294,
#  104295,
#  104296,
#  104297,
#  104298,
#  104299,
#  1043,
#  10430,
#  104300,
#  104301,
#  104302,
#  104303,
#  104304,
#  104305,
#  104306,
#  104307,
#  104308,
#  104309,
#  10431,
#  104310,
#  104311,
#  104312,
#  104313,
#  104314,
#  104315,
#  104316,
#  104317,
#  104318,
#  104319,
#  10432,
#  104320,
#  104321,
#  104322,
#  104323,
#  104324,
#  104325,
#  104326,
#  104327,
#  104328,
#  104329,
#  104369]

# %%
conn = psycopg2.connect(host="chinaquant.cofdbub8go3o.eu-west-1.rds.amazonaws.com",
                        database="postgres",
                        user="tokyo3",
                        password="evangelion")

cur = conn.cursor()
command = """
ALTER TABLE documents 
ADD COLUMN doc_skip SMALLINT
"""
cur.execute(command)
conn.commit()

# extract = cur.fetchall()
# print(extract)
cur.close()
conn.close()

# %%
conn = psycopg2.connect(host="chinaquant.cofdbub8go3o.eu-west-1.rds.amazonaws.com",
                        database="postgres",
                        user="tokyo3",
                        password="evangelion")

cur = conn.cursor()

command = """
SELECT column_name
FROM information_schema.columns
WHERE table_name = 'documents'
"""

cur.execute(command)

columns = cur.fetchall()


# extract = cur.fetchall()
# print(extract)
cur.close()
conn.close()

# %%
columns
# Out:
# [('doc_id',),
#  ('doc_country',),
#  ('doc_language',),
#  ('doc_page_name',),
#  ('doc_url',),
#  ('doc_nav',),
#  ('doc_title',),
#  ('doc_date',),
#  ('doc_html',),
#  ('doc_content',),
#  ('doc_skip',)]

# %%
conn = psycopg2.connect(host="chinaquant.cofdbub8go3o.eu-west-1.rds.amazonaws.com",
                        database="postgres",
                        user="tokyo3",
                        password="evangelion")

cur = conn.cursor()

sql = """
        UPDATE documents
        SET doc_skip = 1
        WHERE doc_id IN {};
        """.format(tuple(skiplist))

cur.execute(sql)
conn.commit()



# extract = cur.fetchall()
# print(extract)
cur.close()
conn.close()

# %%
conn = psycopg2.connect(host="chinaquant.cofdbub8go3o.eu-west-1.rds.amazonaws.com",
                        database="postgres",
                        user="tokyo3",
                        password="evangelion")

cur = conn.cursor()

sql = """
        SELECT * 
        FROM documents
        WHERE doc_skip = 1
        LIMIT 10
        """

cur.execute(sql)

sample = cur.fetchall()

# extract = cur.fetchall()
# print(extract)
cur.close()
conn.close()

# %%
sample
# Out:
# [(10426,
#   '尼日利亚',
#   'zh',
#   '驻外报道',
#   'https://www.fmprc.gov.cn/web/gjhdq_676201/gj_676203/fz_677316/1206_678356/1206x2_678376/t1577156.shtml',
#   '首页_国家和组织_国家（地区）_非洲_尼日利亚_驻外报道_',
#   '驻尼日利亚使馆举办第四届领事论坛(2018-07-14)',
#   datetime.date(2018, 7, 14),
#   None,
#   None,
#   1),
#  (10427,
#   '尼日利亚',
#   'zh',
#   '驻外报道',
#   'https://www.fmprc.gov.cn/web/gjhdq_676201/gj_676203/fz_677316/1206_678356/1206x2_678376/t1577154.shtml',
#   '首页_国家和组织_国家（地区）_非洲_尼日利亚_驻外报道_',
#   '驻尼日利亚大使周平剑出席阿布贾城铁开通运营仪式(2018-07-14)',
#   datetime.date(2018, 7, 14),
#   None,
#   None,
#   1),
#  (104257,
#   '澳大利亚',
#   'zh',
#   '驻外报道',
#   'https://www.fmprc.gov.cn/web/gjhdq_676201/gj_676203/dyz_681240/1206_681242/1206x2_681262/t1195247.shtml',
#   '首页_国家和组织_国家（地区）_大洋洲_澳大利亚_驻外报道_',
#   '驻布里斯班总领事赵永琛在庆祝中华人民共和国成立65周年招待会上的讲话(2014-09-26)',
#   datetime.date(2014, 9, 26),
#   None,
#   None,
#   1),
#  (104258,
#   '澳大利亚',
#   'zh',
#   '驻外报道',
#   'https://www.fmprc.gov.cn/web/gjhdq_676201/gj_676203/dyz_681240/1206_681242/1206x2_681262/t1195229.shtml',
#   '首页_国家和组织_国家（地区）_大洋洲_澳大利亚_驻外报道_',
#   '中国驻布里斯班总领馆举行庆祝中华人民共和国成立65周年招待会(2014-09-26)',
#   datetime.date(2014, 9, 26),
#   None,
#   None,
#   1),
#  (104259,
#   '澳大利亚',
#   'zh',
#   '驻外报道',
#   'https://www.fmprc.gov.cn/web/gjhdq_676201/gj_676203/dyz_681240/1206_681242/1206x2_681262/t1195131.shtml',
#   '首页_国家和组织_国家（地区）_大洋洲_澳大利亚_驻外报道_',
#   '驻珀斯总领事黄亲国在澳中商会（ACBC）国庆晚宴上的致辞(2014-09-26)',
#   datetime.date(2014, 9, 26),
#   None,
#   None,
#   1),
#  (104260,
#   '澳大利亚',
#   'zh',
#   '驻外报道',
#   'https://www.fmprc.gov.cn/web/gjhdq_676201/gj_676203/dyz_681240/1206_681242/1206x2_681262/t1195132.shtml',
#   '首页_国家和组织_国家（地区）_大洋洲_澳大利亚_驻外报道_',
#   '驻珀斯总领事黄亲国出席澳中商会（ACBC）国庆晚宴并致辞(2014-09-26)',
#   datetime.date(2014, 9, 26),
#   None,
#   None,
#   1),
#  (104261,
#   '澳大利亚',
#   'zh',
#   '驻外报道',
#   'https://www.fmprc.gov.cn/web/gjhdq_676201/gj_676203/dyz_681240/1206_681242/1206x2_681262/t1195126.shtml',
#   '首页_国家和组织_国家（地区）_大洋洲_澳大利亚_驻外报道_',
#   '驻珀斯总领馆举办2014“中国人眼中的西澳”摄影图片展(2014-09-25)',
#   datetime.date(2014, 9, 25),
#   None,
#   None,
#   1),
#  (10432,
#   '尼日利亚',
#   'zh',
#   '驻外报道',
#   'https://www.fmprc.gov.cn/web/gjhdq_676201/gj_676203/fz_677316/1206_678356/1206x2_678376/t1574554.shtml',
#   '首页_国家和组织_国家（地区）_非洲_尼日利亚_驻外报道_',
#   '驻拉各斯总领事巢小良会见华为尼日利亚分公司总经理李北方(2018-07-06)',
#   datetime.date(2018, 7, 6),
#   None,
#   None,
#   1),
#  (104312,
#   '澳大利亚',
#   'zh',
#   '驻外报道',
#   'https://www.fmprc.gov.cn/web/gjhdq_676201/gj_676203/dyz_681240/1206_681242/1206x2_681262/t1157109.shtml',
#   '首页_国家和组织_国家（地区）_大洋洲_澳大利亚_驻外报道_',
#   '驻澳大利亚大使马朝旭出席澳中关系研究院成立仪式(2014-05-18)',
#   datetime.date(2014, 5, 18),
#   None,
#   None,
#   1),
#  (104313,
#   '澳大利亚',
#   'zh',
#   '驻外报道',
#   'https://www.fmprc.gov.cn/web/gjhdq_676201/gj_676203/dyz_681240/1206_681242/1206x2_681262/t1157092.shtml',
#   '首页_国家和组织_国家（地区）_大洋洲_澳大利亚_驻外报道_',
#   '驻澳大利亚大使马朝旭为第20轮中澳自贸协定谈判代表团举行招待会(2014-05-18)',
#   datetime.date(2014, 5, 18),
#   None,
#   None,
#   1)]

# %%
# conn = psycopg2.connect(host="chinaquant.cofdbub8go3o.eu-west-1.rds.amazonaws.com",
#                         database="postgres",
#                         user="tokyo3",
#                         password="evangelion")

# cur = conn.cursor()

# command = """
# SELECT doc_id,doc_url
# FROM documents
# WHERE doc_url NOT SIMILAR TO '%shtml' AND doc_id NOT IN {}
# """.format(tuple(skiplist))


# cur.execute(command)

# extract = cur.fetchall()
# print(extract)
# cur.close()
# conn.close()

# %%
# submission[-1]

# %%
# for i in submission:
#     print(i[2],'\n')

# %%
# print(len(submission))

# %%
# for i in submission:
#     if i[2] == 'ERROR':
#         print(i[3])

# %%
# newSubmission = []
# for i in submission:
#     if i[1] == 'ERROR':
#         skiplist.append(i[3])
#     else:
#         newSubmission.append(i)

# %%
# pd.Series(skiplist).to_csv('skiplist.csv')

# %%
# pd.Series(skiplist)

# %%
# conn = psycopg2.connect(host="chinaquant.cofdbub8go3o.eu-west-1.rds.amazonaws.com",
#                         database="postgres",
#                         user="tokyo3",
#                         password="evangelion")

# cur = conn.cursor()

# %%
# sql = """
#         UPDATE documents
#         SET doc_html = %s,doc_date = %s,doc_content = %s
#         WHERE doc_id = %s;
#         """

# cur.executemany(sql,newSubmission)
# conn.commit()

# cur.close()
# conn.close()

# %%
# existing

# %%
# len(existing)

# %%
# listCheck = [x[0] for x in existing]

# %%
# listCheck

# %%
# tuple(listCheck)

# %%
# conn = psycopg2.connect(host="chinaquant.cofdbub8go3o.eu-west-1.rds.amazonaws.com",
#                         database="postgres",
#                         user="tokyo3",
#                         password="evangelion")

# cur = conn.cursor()

# command = """
# SELECT *
# FROM documents
# WHERE doc_id IN {}
# """.format(tuple(listCheck))

# cur.execute(command)

# extract = cur.fetchall()

# cur.close()
# conn.close()

# %%
# conn = psycopg2.connect(host="chinaquant.cofdbub8go3o.eu-west-1.rds.amazonaws.com",
#                         database="postgres",
#                         user="tokyo3",
#                         password="evangelion")

# cur = conn.cursor()

# command = """
# SELECT COUNT(doc_id)
# FROM documents
# WHERE doc_html IS NULL AND doc_date IS NULL and doc_id NOT IN {}
# """.format(tuple(skiplist))


# cur.execute(command)

# extract = cur.fetchall()

# cur.close()
# conn.close()

# %%
# extract
