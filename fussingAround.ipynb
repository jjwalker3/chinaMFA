# %%
import pandas as pd
import Beautiful

# %%
df = pd.read_json("full_documents.json")

# %%
df.head()
# Out:
#                                                 content country        date  \
# 0     <html xmlns="http://www.w3.org/1999/xhtml"><he...     阿富汗  2018-09-06
# 1     <html xmlns="http://www.w3.org/1999/xhtml"><he...     阿富汗  2018-06-10
# 10    <html xmlns="http://www.w3.org/1999/xhtml"><he...     尼泊尔  2013-05-14
# 100   <html xmlns="http://www.w3.org/1999/xhtml"><he...     尼泊尔  2013-01-15
# 1000  <html xmlns="http://www.w3.org/1999/xhtml"><he...   哥斯达黎加  2018-05-17
#
#      lang  more                              nav  page  \
# 0      zh   NaN     首页_国家和组织_国家（地区）_亚洲_阿富汗_相关新闻_  相关新闻
# 1      zh   NaN     首页_国家和组织_国家（地区）_亚洲_阿富汗_相关新闻_  相关新闻
# 10     zh   NaN     首页_国家和组织_国家（地区）_亚洲_尼泊尔_驻外报道_  驻外报道
# 100    zh   NaN     首页_国家和组织_国家（地区）_亚洲_尼泊尔_驻外报道_  驻外报道
# 1000   zh   NaN  首页_国家和组织_国家（地区）_北美洲_哥斯达黎加_驻外报道_  驻外报道
#
#                                        title  \
# 0       外交部副部长孔铉佑会见阿富汗离任驻华大使莫萨扎伊(2018-09-06)
# 1                   习近平会见阿富汗总统加尼(2018-06-10)
# ...

# %%
df.loc[0,'url']
# Out:
# 'https://www.fmprc.gov.cn/web/gjhdq_676201/gj_676203/yz_676205/1206_676207/xgxw_676213/t1592439.shtml'

# %%
df.to_excel("full_documents_fiddling.xlsx")
