# %%
# instance dbtest
# username tokyo6
# password shinjiikari
# dbname dbtestname

from bs4 import BeautifulSoup
from selenium import webdriver
import os
import psycopg2

# %%
print(configPath)
# Out:
# C:\Users\jjw4418\_notebooks\chinaMFA\config.txt

# %%
from bs4 import BeautifulSoup
from selenium import webdriver
from selenium.webdriver.firefox.options import Options
import os
import psycopg2

def main():
    options = Options()
    options.add_argument("--headless")
    
    scriptPath = os.getcwd()
    driverPath = scriptPath + '\\' + 'geckodriver.exe'

    
    driver = webdriver.Firefox(options=options, executable_path=driverPath)
    driver.get("https://www.bbc.com/news")
    html = driver.page_source
    soup=BeautifulSoup(html, 'lxml')
    pageText = soup.find(class_='gs-c-promo-heading gs-o-faux-block-link__overlay-link gel-paragon-bold nw-o-link-split__anchor').text
    
    conn = psycopg2.connect(host="dbtest123.cofdbub8go3o.eu-west-1.rds.amazonaws.com",
                        database="dbtestname",
                        user="tokyo6",
                        password="shinjiikari")

    cur = conn.cursor()

    command = """
    INSERT INTO testtable(content,datetime)
    VALUES(%s,current_timestamp);
    """
    

    cur.execute(command,(pageText,))
    conn.commit()

    cur.close()
    conn.close()


if __name__ == '__main__':
    main()

# %%
conn = psycopg2.connect(host="dbtest123.cofdbub8go3o.eu-west-1.rds.amazonaws.com",
                        database="dbtestname",
                        user="tokyo6",
                        password="shinjiikari")

cur = conn.cursor()

command = """
SELECT *
FROM testtable
"""

cur.execute(command)

datafetch = cur.fetchall()

cur.close()
conn.close()

for i in datafetch:
    print(i)
# Out:
# (4, 'jw manual update', datetime.datetime(2019, 1, 27, 15, 42, 22, 125365))
# (5, 'jw manual update', datetime.datetime(2019, 1, 27, 15, 42, 55, 153835))
# (6, 'Brazil search resumes after new dam scare', datetime.datetime(2019, 1, 27, 17, 54, 58, 214594))
# (7, 'Brazil search resumes after new dam scare', datetime.datetime(2019, 1, 27, 17, 55, 36, 979506))
# (8, 'Brazil search resumes after new dam scare', datetime.datetime(2019, 1, 27, 18, 5, 43, 486292))
# (9, 'Brazil search resumes after new dam scare', datetime.datetime(2019, 1, 27, 18, 6, 23, 652172))
# (10, 'Brazil search resumes after new dam scare', datetime.datetime(2019, 1, 27, 18, 6, 55, 320472))
# (11, 'Brazil search resumes after new dam scare', datetime.datetime(2019, 1, 27, 18, 7, 16, 30471))
# (12, 'Brazil search resumes after new dam scare', datetime.datetime(2019, 1, 27, 18, 8, 11, 726151))
# (13, 'Brazil search resumes after new dam scare', datetime.datetime(2019, 1, 27, 18, 8, 30, 285392))
# (14, 'Brazil search resumes after new dam scare', datetime.datetime(2019, 1, 27, 18, 9, 28, 177810))
# (15, 'Brazil search resumes after new dam scare', datetime.datetime(2019, 1, 27, 18, 23, 32, 26559))
# (16, "US 'will respond to Venezuela threats'", datetime.datetime(2019, 1, 27, 21, 22, 36, 152935))
# (17, "US 'will respond to Venezuela threats'", datetime.datetime(2019, 1, 27, 21, 32, 16, 372053))
# (18, 'Travel ban for Venezuela opposition head', datetime.datetime(2019, 1, 30, 10, 50, 49, 37394))
# (19, 'Travel ban for Venezuela opposition head', datetime.datetime(2019, 1, 30, 10, 51, 13, 977090))
# (20, 'Travel ban for Venezuela opposition head', datetime.datetime(2019, 1, 30, 11, 1, 5, 896495))
# (21, 'Travel ban for Venezuela opposition head', datetime.datetime(2019, 1, 30, 11, 1, 19, 869568))
# (22, 'UK PM set for further talks with EU leaders', datetime.datetime(2019, 1, 30, 11, 18, 47, 694619))
# (23, 'UK PM set for further talks with EU leaders', datetime.datetime(2019, 1, 30, 11, 19, 11, 488977))
# (24, "EU 'united' on Brexit deal, says Barnier", datetime.datetime(2019, 1, 30, 11, 23, 20, 104879))
# (25, 'UK PM set for further talks with EU leaders', datetime.datetime(2019, 1, 30, 11, 28, 14, 394638))
# (26, 'UK PM set for further talks with EU leaders', datetime.datetime(2019, 1, 30, 11, 28, 33, 737468))
# (27, "EU 'united' on Brexit deal, says Barnier", datetime.datetime(2019, 1, 30, 12, 28, 53, 200216))
# (28, 'UK PM set for further talks with EU leaders', datetime.datetime(2019, 1, 30, 12, 30, 2, 537398))
# (29, 'UK PM set for further talks with EU leaders', datetime.datetime(2019, 1, 30, 12, 34, 43, 738031))
# (30, 'Deadly polar vortex hits swathes of US', datetime.datetime(2019, 1, 30, 12, 47, 37, 402138))
# (31, 'Deadly polar vortex hits swathes of US', datetime.datetime(2019, 1, 30, 12, 48, 0, 602109))
# (32, 'Deadly polar vortex hits swathes of US', datetime.datetime(2019, 1, 30, 12, 48, 18, 285651))
# (33, 'UK PM set for further talks with EU leaders', datetime.datetime(2019, 1, 30, 12, 59, 41, 192980))
# (34, 'UK PM set for further talks with EU leaders', datetime.datetime(2019, 1, 30, 13, 0, 2, 64308))
# (35, 'UK PM set for further talks with EU leaders', datetime.datetime(2019, 1, 30, 13, 1, 6, 253077))
# (36, 'UK PM set for further talks with EU leaders', datetime.datetime(2019, 1, 30, 13, 12, 29, 434747))
# (37, 'UK PM set for further talks with EU leaders', datetime.datetime(2019, 1, 30, 13, 17, 24, 651769))
# (38, 'UK PM set for further talks with EU leaders', datetime.datetime(2019, 1, 30, 13, 23, 14, 751574))
# (39, 'Deadly polar vortex hits swathes of US', datetime.datetime(2019, 1, 30, 13, 46, 46, 152588))

# %%
# conn = psycopg2.connect(host="dbtest123.cofdbub8go3o.eu-west-1.rds.amazonaws.com",
#                         database="dbtestname",
#                         user="tokyo6",
#                         password="shinjiikari")

# cur = conn.cursor()

# command = """
#     CREATE TABLE testtable (
#     table_id  SERIAL PRIMARY KEY,
#     content VARCHAR(255) NOT NULL,
#     datetime TIMESTAMP default current_timestamp
#     )
#     """
# cur.execute(command)
# conn.commit()

# cur.close()
# conn.close()

# %%
conn = psycopg2.connect(host="dbtest123.cofdbub8go3o.eu-west-1.rds.amazonaws.com",
                        database="dbtestname",
                        user="tokyo6",
                        password="shinjiikari")

cur = conn.cursor()

command = """
SELECT column_name
FROM information_schema.columns
WHERE table_name = 'testtable'
"""

cur.execute(command)

columns = cur.fetchall()


cur.close()
conn.close()

# %%
conn = psycopg2.connect(host="dbtest123.cofdbub8go3o.eu-west-1.rds.amazonaws.com",
                        database="dbtestname",
                        user="tokyo6",
                        password="shinjiikari")

cur = conn.cursor()

command = """
INSERT INTO testtable(content,datetime)
VALUES(%s,current_timestamp);
"""
data = "jw manual update"

cur.execute(command,(data,))
conn.commit()

cur.close()
conn.close()

# %%
conn = psycopg2.connect(host="dbtest123.cofdbub8go3o.eu-west-1.rds.amazonaws.com",
                        database="dbtestname",
                        user="tokyo6",
                        password="shinjiikari")

cur = conn.cursor()

command = """
SELECT *
FROM testtable
"""

cur.execute(command)

datafetch = cur.fetchall()


cur.close()
conn.close()

# %%
datafetch

# %%
conn = psycopg2.connect(host="chinaquant.cofdbub8go3o.eu-west-1.rds.amazonaws.com",
                        database="postgres",
                        user="tokyo3",
                        password="evangelion")

cur = conn.cursor()
cur.close()
conn.close()

# %%
# command = """
# SELECT count(doc_id)
# FROM documents
# WHERE doc_html IS NULL AND doc_date IS NOT NULL and doc_id NOT IN {}

# """.format(tuple(skiplist))

# cur.execute(command)

# existing = cur.fetchall()

# %%
os.getcwd()

# %%
# main()

# %%
conn = psycopg2.connect(host="dbtest123.cofdbub8go3o.eu-west-1.rds.amazonaws.com",
                        database="dbtestname",
                        user="tokyo6",
                        password="shinjiikari")

cur = conn.cursor()

command = """
SELECT *
FROM testtable
"""

cur.execute(command)

datafetch = cur.fetchall()

cur.close()
conn.close()

for i in datafetch:
    print(i)

# %%
# def html(url):
#     try:
#         driver.get(url)
#         html = driver.page_source
#         if type(html) == str:
#             return(html)
#         else:
#             return('ERROR')
#     except:
#         return('ERROR')

# %%
# def headlessDriver():
#     options = Options()
#     options.add_argument("--headless")
#     driver = webdriver.Firefox(options=options, executable_path="geckodriver.exe")
#     return(driver)

# %%
# def buildEntry(index_value,url):
#     t_start = time.time()
    
#     index = index_value
#     pageSource = html(url)
# #     pageDate = str()
#     pageText = str()
#     if pageSource == 'ERROR':
# #         pageDate = 'ERROR'
#         pageText = 'ERROR'
#     else:
#         try:
#             soup=BeautifulSoup(pageSource, 'lxml')
# #             pageDate = soup.find("span", {"id": "News_Body_Time"}).text
# #             if pageDate == '':
# #                 pageDate = None
#             pageText = soup.find(class_='content').text
#             if pageText == '':
#                 pageText = None
#         except:
# #             pageDate = 'ERROR'
#             pageText = 'ERROR'
    
#     entry = (pageSource,
# #              pageDate,
#              pageText,
#              index)
    
#     t_end = time.time()
    
#     duration = t_end - t_start
    
#     if duration >= 10:
#         time.sleep(np.random.randint(5,15))
    
# #   print(duration)          
#     return(entry)
